# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#plt.style.use('ggplot')
plt.xkcd()
#plt.style.use('fivethirtyeight')
age_dev = [25, 26, 26, 27, 28, 29, 30]
dev_y = [300000, 320000, 380000, 410000, 450000, 500000, 520000]
#plt.plot(age_dev, dev_y, color='k', linestyle='--', marker='o', label = 'all devs')
plt.plot(age_dev, dev_y, label = 'all devs')
plt.title('Average of salary')
plt.xlabel('The age of people')
plt.ylabel('The salary of people')
py_dev_y = [280000, 340000, 370000, 430000, 480000, 510000, 550000]
#plt.plot(age_dev, py_dev_y,  linestyle='-.', linewidth='2', marker='.', color='r', label='Python')
plt.plot(age_dev, py_dev_y, label='Python')
js_dev_y = [300000, 340000, 390000, 440000, 480000, 490000, 530000]
#plt.plot(age_dev, js_dev_y, color='b', label="JavaScript" )
plt.plot(age_dev, js_dev_y, label="JavaScript" )
plt.legend()
#plt.grid(True)
plt.savefig('plot.png')
plt.show()
#print(plt.style.available)
